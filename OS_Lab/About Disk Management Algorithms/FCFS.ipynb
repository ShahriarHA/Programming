# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tracks = int(input("enter the number of tracks: "))
# Out:
# enter the number of tracks: 200

# %%
queue_track_no = input("enter the request queue contains track no separate them using comma: ",)
queue_track_no_list = queue_track_no.split(",")
print(queue_track_no_list)
# Out:
# enter the request queue contains track no separate them using comma: 88,150,44,172,30,15,195
# ['88', '150', '44', '172', '30', '15', '195']

# %%
queue_track_no_list = [int(i) for i in queue_track_no_list]
print(queue_track_no_list)
# Out:
# [88, 150, 44, 172, 30, 15, 195]

# %%
position_r_w_head = int(input("enter the position of r/w head: "))
# Out:
# enter the position of r/w head: 50

# %%
fcfs = np.zeros(tracks)
# print(fcfs)

# %%
queue_track_no_list.insert(0,position_r_w_head)
print(queue_track_no_list)
# Out:
# [50, 88, 150, 44, 172, 30, 15, 195]

# %%
plt.plot(queue_track_no_list,marker = 'o')
# plt.scatter(queue_track_no_list)
# plt.stem(queue_track_no_list)

# %%
plt.plot(queue_track_no_list)
